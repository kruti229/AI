# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras.utils import to_categorical
#
# Create the network
#
network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(4,)))
network.add(layers.Dense(3, activation='softmax'))

# Compile the network
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# Load the iris dataset

iris = datasets.load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
#
# Create categorical labels
#
train_labels = to_categorical(y_train)
test_labels = to_categorical(y_test)

# Fit the neural network

network.fit(X_train, train_labels, epochs=20, batch_size=40)
# Get the accuracy of test data set
test_loss, test_acc = network.evaluate(X_test, test_labels)

print('Test Accuracy: ', test_acc, '\nTest Loss: ', test_loss)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 1s 10ms/step - loss: 1.0542 - accuracy: 0.4286
# Epoch 2/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8470 - accuracy: 0.8095
# Epoch 3/20
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7677 - accuracy: 0.7905
# Epoch 4/20
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6995 - accuracy: 0.8381
# Epoch 5/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6623 - accuracy: 0.7810
# Epoch 6/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6184 - accuracy: 0.7524
# Epoch 7/20
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6510 - accuracy: 0.7143
# Epoch 8/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5840 - accuracy: 0.7238
# Epoch 9/20
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5412 - accuracy: 0.7429
# Epoch 10/20
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5315 - accuracy: 0.8286
# Epoch 11/20
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5009 - accuracy: 0.8476
# Epoch 12/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5010 - accuracy: 0.7810
# Epoch 13/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4696 - accuracy: 0.9333
# Epoch 14/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4605 - accuracy: 0.8381
# Epoch 15/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4357 - accuracy: 0.8286
# Epoch 16/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4180 - accuracy: 0.9333
# Epoch 17/20
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4255 - accuracy: 0.8476
# Epoch 18/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4123 - accuracy: 0.8762
# Epoch 19/20
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3951 - accuracy: 0.8857
# Epoch 20/20
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3759 - accuracy: 0.8952
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4174 - accuracy: 0.7111
# Test Accuracy:  0.7111111283302307
# Test Loss:  0.41737106442451477

# %%
clx.predict([[1,0.9]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7056\3500844598.py in <module>
# ----> 1 clx.predict([[1,0.9]])
#
# NameError: name 'clx' is not defined
